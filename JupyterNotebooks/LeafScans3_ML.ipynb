# %% [markdown]
# # LeafScans WorkBook 3
# * Create Train-Test Loop for ML predictions
#     * Partial Least Squares Regression
#     * Random Forrest Regression
#     * Support Vector Machine Regression
# * For each ML algorithm and for each target data set (leaf nutes or leaf gas exchange data)
#     * Split into 5 random folds with respect to genotype (avoid data leakage)
#     * Use grid search and recursive feature elimination (not for svm) to optimize model hyperparams in training set
#     * Apply and record R2 on testing set and record score

# %%
# Import modules
# Fundamental data manipulationa nd visualization packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


# machine learning and data preprocessing tools from sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cross_decomposition import PLSRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import GridSearchCV


# set seed for torch and other ML functions
np.random.seed(42)

# %%
df_nutes = pd.read_csv(r'../Data/NuteScansAll_merged.csv')
df_gasex = pd.read_csv(r'../Data/GasExScansAll_Merged.csv')
# Calculate NDVI based on lit
df_nutes['ndvi'] = (df_nutes['800'] - df_nutes['651'])/(df_nutes['800'] + df_nutes['651'])
df_nutes_R2 = df_nutes[df_nutes['DevStage'] == 'R2'].reset_index()
# Wavelengths list usefule for graphing and looping
wavelengths = df_gasex.columns[20:355].astype(str)

# %%
def pls_variable_selection(X, y, max_comp):
    # Create an empty array to store mse values
    mse = np.zeros((max_comp,X.shape[1]))
    # Outer loop optimizes num of components
    for i in range(max_comp):
        #print(X.shape, y.shape)
        #print(i)
        pls1 = PLSRegression(n_components=i+1)
        pls1.fit(X, y)
        sorted_ind = np.argsort(np.abs(pls1.coef_[0]))
        #print(sorted_ind)
        Xc = X[:,sorted_ind]
        # Inner loop optimizes input features
        for j in range(Xc.shape[1]-(i+1)):
            pls2 = PLSRegression(n_components=i+1)
            pls2.fit(Xc[:, j:], y)
            p = cross_val_score(pls2, Xc[:, j:], y, scoring = 'neg_mean_squared_error')
            p = np.mean(np.abs(p))
            mse[i,j] = p
        comp = 100*(i+1)/(max_comp)
    #Calculate and print the position of minimum in MSE
    mseminx,mseminy = np.where(mse==np.min(mse[np.nonzero(mse)]))
    rpd_cv = y.std()/np.sqrt(mse[mseminx,mseminy][0])
    print("Optimised number of PLS components: ", mseminx[0]+1)
    print("Wavelengths to be discarded ",mseminy[0])
    print('Optimised MSEP ', mse[mseminx,mseminy][0])
    print('RPD CV', rpd_cv)
    # Build model with optimisez params for output
    Opt_components = mseminx[0]+1
    pls = PLSRegression(n_components=Opt_components)
    pls.fit(X, y)
    sorted_ind = np.argsort(np.abs(pls.coef_[0]))
    Xc = X[:, sorted_ind]
    wavD = mseminy[0]
    # Slice of sorted X matrix that only contains kept wavelengths
    Opt_x = Xc[:, wavD:]
    pls.fit(Opt_x, y)
    return (pls, Opt_components, wavD, sorted_ind)

# %%
print(df_gasex.columns[3:8])
targets = list(df_gasex.columns[3:8])
gkf = GroupKFold(n_splits=5)
# Out:
# Index(['E', 'A', 'Ci', 'gsw', 'WUE'], dtype='object')

# %%
scores = {}
for target in targets:
    y = df_gasex[target].values
    x = df_gasex[wavelengths].values
    groups = np.array(df_gasex['Name'])
    scores[target] = []
    i = 0

    for train_ind, test_ind in gkf.split(X = x, y = y, groups = groups):
        #print(df_gasex.loc[test_ind, 'Name'])
        pls, Opt_components, wavD, sorted_ind = pls_variable_selection(x[train_ind], y[train_ind], 9)
        #sns.histplot(x = y[test_ind].flatten(), hue = df_gasex.loc[test_ind, 'Ntreatment'])
        #plt.title(target + '-CV{}'.format(i))
        #plt.show()
        i += 1
        x_test = x[test_ind]
        x_test = x_test[:, sorted_ind]
        x_test = x_test[:, wavD:]
        y_predict = pls.predict(x_test)
        r2 = r2_score(y[test_ind], y_predict)
        print('External Validation Goodness-of-Fit', r2)
        scores[target].append(r2)

df_scores_GasExPLSR = pd.DataFrame(scores)
# df_scores_GasExPLSR.to_csv('Scores_GasExPLSR.csv', index = False)
# Out:
# Optimised number of PLS components:  6
# Wavelengths to be discarded  328
# Optimised MSEP  7.414408367227667e-07
# RPD CV 1.146807949776514
# External Validation Goodness-of-Fit 0.304150732527382
# Optimised number of PLS components:  9
# Wavelengths to be discarded  285
# Optimised MSEP  7.724284391788038e-07
# RPD CV 1.2083254839455317
# External Validation Goodness-of-Fit 0.26135255928161993
# Optimised number of PLS components:  9
# Wavelengths to be discarded  285
# Optimised MSEP  8.127483078265106e-07
# RPD CV 1.1943125742017064
# External Validation Goodness-of-Fit 0.104097445379565
# Optimised number of PLS components:  9
# Wavelengths to be discarded  312
# Optimised MSEP  7.523717530374632e-07
# RPD CV 1.222830309107544
# External Validation Goodness-of-Fit -0.20486216824259373
# Optimised number of PLS components:  9
# Wavelengths to be discarded  301
# Optimised MSEP  7.72355298804157e-07
# RPD CV 1.1912239146149006
# External Validation Goodness-of-Fit 0.13395211323472667
# Optimised number of PLS components:  9
# Wavelengths to be discarded  287
# Optimised MSEP  21.84083195159254
# RPD CV 1.188070211256865
# External Validation Goodness-of-Fit 0.26995445160665177
# Optimised number of PLS components:  9
# Wavelengths to be discarded  235
# Optimised MSEP  19.982047617746822
# RPD CV 1.2778114534981657
# External Validation Goodness-of-Fit 0.02432354890316446
# Optimised number of PLS components:  9
# Wavelengths to be discarded  286
# Optimised MSEP  22.5862912279214
# RPD CV 1.2237767819648304
# External Validation Goodness-of-Fit 0.1815476316784801
# Optimised number of PLS components:  9
# Wavelengths to be discarded  289
# Optimised MSEP  23.28202984645877
# RPD CV 1.2050708857858243
# External Validation Goodness-of-Fit 0.1651565772055933
# Optimised number of PLS components:  8
# Wavelengths to be discarded  311
# Optimised MSEP  24.88985647528899
# RPD CV 1.1626179114705322
# External Validation Goodness-of-Fit 0.4056757678026801
# Optimised number of PLS components:  8
# Wavelengths to be discarded  311
# Optimised MSEP  3745.0204838911473
# RPD CV 1.1758580142190422
# External Validation Goodness-of-Fit 0.3020603779360975
# Optimised number of PLS components:  9
# Wavelengths to be discarded  306
# Optimised MSEP  3016.421990480873
# RPD CV 1.24499468849174
# External Validation Goodness-of-Fit 0.32949680432961814
# Optimised number of PLS components:  9
# Wavelengths to be discarded  317
# Optimised MSEP  3374.902889721006
# RPD CV 1.1966693173393348
# External Validation Goodness-of-Fit 0.2518748301088628
# Optimised number of PLS components:  9
# Wavelengths to be discarded  301
# Optimised MSEP  2672.3842688794057
# RPD CV 1.3339301177086975
# External Validation Goodness-of-Fit 0.19094698683272004
# Optimised number of PLS components:  9
# Wavelengths to be discarded  309
# Optimised MSEP  3132.878755630648
# RPD CV 1.191233695962413
# External Validation Goodness-of-Fit 0.27673369110843093
# Optimised number of PLS components:  3
# Wavelengths to be discarded  311
# Optimised MSEP  0.0022267977201614365
# RPD CV 1.0333913074776202
# External Validation Goodness-of-Fit 0.18113911814189687
# Optimised number of PLS components:  9
# Wavelengths to be discarded  211
# Optimised MSEP  0.0023074539560466846
# RPD CV 1.0433512833084648
# External Validation Goodness-of-Fit -0.12570990041421393
# Optimised number of PLS components:  4
# Wavelengths to be discarded  320
# Optimised MSEP  0.002262926223960773
# RPD CV 1.0691612551063565
# External Validation Goodness-of-Fit 0.04126026210477829
# Optimised number of PLS components:  4
# Wavelengths to be discarded  328
# Optimised MSEP  0.00216304100641788
# RPD CV 1.065649953300794
# External Validation Goodness-of-Fit -0.1258441666580672
# Optimised number of PLS components:  1
# Wavelengths to be discarded  312
# Optimised MSEP  0.002249086021992803
# RPD CV 1.061740113581094
# External Validation Goodness-of-Fit -0.0768134252142465
# Optimised number of PLS components:  9
# Wavelengths to be discarded  321
# Optimised MSEP  1330.465973262803
# RPD CV 1.1366326968701592
# External Validation Goodness-of-Fit 0.27073710180220745
# Optimised number of PLS components:  9
# Wavelengths to be discarded  308
# Optimised MSEP  1101.322558028889
# RPD CV 1.191375397991219
# External Validation Goodness-of-Fit 0.3541454692448396
# Optimised number of PLS components:  9
# Wavelengths to be discarded  322
# Optimised MSEP  1213.593877216615
# RPD CV 1.14653642292134
# External Validation Goodness-of-Fit 0.2675989874252027
# Optimised number of PLS components:  9
# Wavelengths to be discarded  290
# Optimised MSEP  971.6604785154561
# RPD CV 1.273441380654761
# External Validation Goodness-of-Fit 0.02204987935846303
# Optimised number of PLS components:  9
# Wavelengths to be discarded  312
# Optimised MSEP  1100.3516298997329
# RPD CV 1.161325874582127
# External Validation Goodness-of-Fit 0.2466498155461181

# %%
df_scores_GasExPLSR.to_clipboard()

# %%
# Same for Nutes
gkf = GroupKFold(n_splits=5)
print(df_nutes.columns[18:30])
targets = list(df_nutes.columns[18:30])
# Out:
# Index(['N', 'P', 'K', 'Ca', 'Mg', 'Na', 'S', 'Zn', 'Mn', 'Fe', 'Cu', 'B'], dtype='object')

# %%
scores = {}
for target in targets:
    y = df_nutes_R2[target].values
    x = df_nutes_R2[wavelengths].values
    groups = np.array(df_nutes_R2['Hybrid'])
    scores[target] = []
    i = 0

    for train_ind, test_ind in gkf.split(X = x, y = y, groups = groups):
        #print(df_gasex.loc[test_ind, 'Name'])
        pls, Opt_components, wavD, sorted_ind = pls_variable_selection(x[train_ind], y[train_ind], 9)
        #sns.histplot(x = y[test_ind].flatten(), hue = df_gasex.loc[test_ind, 'Ntreatment'])
        #plt.title(target + '-CV{}'.format(i))
        #plt.show()
        i += 1
        x_test = x[test_ind]
        x_test = x_test[:, sorted_ind]
        x_test = x_test[:, wavD:]
        y_predict = pls.predict(x_test)
        r2 = r2_score(y[test_ind], y_predict)
        print('External Validation Goodness-of-Fit', r2)
        scores[target].append(r2)

df_scores_NutesPLSR = pd.DataFrame(scores)
df_scores_NutesPLSR.to_csv('Scores_NutesPLSR.csv', index = False)
# Out:
# Optimised number of PLS components:  4
# Wavelengths to be discarded  73
# Optimised MSEP  0.07518247341257248
# RPD CV 1.7706935371599193
# External Validation Goodness-of-Fit 0.6405816046081032
# Optimised number of PLS components:  9
# Wavelengths to be discarded  314
# Optimised MSEP  0.06538286550575975
# RPD CV 1.9144271523870053
# External Validation Goodness-of-Fit 0.6786202591289461
# Optimised number of PLS components:  9
# Wavelengths to be discarded  283
# Optimised MSEP  0.06861184003679607
# RPD CV 1.80032952776429
# External Validation Goodness-of-Fit 0.6757323891746749
# Optimised number of PLS components:  9
# Wavelengths to be discarded  315
# Optimised MSEP  0.0630756565596303
# RPD CV 1.9309006632986156
# External Validation Goodness-of-Fit 0.5758553833166442
# Optimised number of PLS components:  4
# Wavelengths to be discarded  130
# Optimised MSEP  0.08572578992021525
# RPD CV 1.6493027551219037
# External Validation Goodness-of-Fit 0.7490779187514431
# Optimised number of PLS components:  9
# Wavelengths to be discarded  308
# Optimised MSEP  0.0007631229449460194
# RPD CV 1.5576022180992546
# External Validation Goodness-of-Fit 0.6646986416750635
# Optimised number of PLS components:  9
# Wavelengths to be discarded  308
# Optimised MSEP  0.0007726255360647404
# RPD CV 1.5875540866300535
# External Validation Goodness-of-Fit 0.6259870759331383
# Optimised number of PLS components:  8
# Wavelengths to be discarded  322
# Optimised MSEP  0.0006455811133495267
# RPD CV 1.6993837657176645
# External Validation Goodness-of-Fit 0.4559518441591026
# Optimised number of PLS components:  4
# Wavelengths to be discarded  327
# Optimised MSEP  0.0007519183088453088
# RPD CV 1.6291752176779168
# External Validation Goodness-of-Fit 0.31097720382195915
# Optimised number of PLS components:  5
# Wavelengths to be discarded  323
# Optimised MSEP  0.0007669018319534239
# RPD CV 1.5216151100169273
# External Validation Goodness-of-Fit 0.5503958019619175
# Optimised number of PLS components:  6
# Wavelengths to be discarded  285
# Optimised MSEP  0.02568813149742266
# RPD CV 1.147566094480516
# External Validation Goodness-of-Fit 0.40613884974944714
# Optimised number of PLS components:  5
# Wavelengths to be discarded  217
# Optimised MSEP  0.027031511679265725
# RPD CV 1.2581414246495264
# External Validation Goodness-of-Fit -0.3560609858515109
# Optimised number of PLS components:  6
# Wavelengths to be discarded  254
# Optimised MSEP  0.030778617298412737
# RPD CV 1.1692082647450086
# External Validation Goodness-of-Fit 0.21707171060445107
# Optimised number of PLS components:  7
# Wavelengths to be discarded  270
# Optimised MSEP  0.026152151939419638
# RPD CV 1.2500673437804006
# External Validation Goodness-of-Fit -0.06550550396301147
# Optimised number of PLS components:  7
# Wavelengths to be discarded  226
# Optimised MSEP  0.029516022563792765
# RPD CV 1.1633794828287887
# External Validation Goodness-of-Fit 0.21822467194444317
# Optimised number of PLS components:  8
# Wavelengths to be discarded  269
# Optimised MSEP  0.008646400710298159
# RPD CV 1.7398262269163922
# External Validation Goodness-of-Fit 0.36240197783836436
# Optimised number of PLS components:  9
# Wavelengths to be discarded  264
# Optimised MSEP  0.011039727010146359
# RPD CV 1.6194012335382533
# External Validation Goodness-of-Fit 0.651520960591762
# Optimised number of PLS components:  9
# Wavelengths to be discarded  254
# Optimised MSEP  0.010644628082534897
# RPD CV 1.6289902409338974
# External Validation Goodness-of-Fit 0.5444608424588788
# Optimised number of PLS components:  8
# Wavelengths to be discarded  219
# Optimised MSEP  0.009137344940074621
# RPD CV 1.693308089472191
# External Validation Goodness-of-Fit 0.4546672340681531
# Optimised number of PLS components:  5
# Wavelengths to be discarded  116
# Optimised MSEP  0.011504514877464329
# RPD CV 1.5766983203681901
# External Validation Goodness-of-Fit 0.42072826118088613
# Optimised number of PLS components:  6
# Wavelengths to be discarded  168
# Optimised MSEP  0.0020055010108972985
# RPD CV 1.3638693205411172
# External Validation Goodness-of-Fit 0.0959798454271964
# Optimised number of PLS components:  6
# Wavelengths to be discarded  312
# Optimised MSEP  0.002088125790135546
# RPD CV 1.3169775909972499
# External Validation Goodness-of-Fit 0.38432010283320517
# Optimised number of PLS components:  6
# Wavelengths to be discarded  319
# Optimised MSEP  0.002088555534103617
# RPD CV 1.301027083136646
# External Validation Goodness-of-Fit 0.24919254654320966
# Optimised number of PLS components:  7
# Wavelengths to be discarded  283
# Optimised MSEP  0.0018846529872223936
# RPD CV 1.2489908576935498
# External Validation Goodness-of-Fit 0.47498418866379677
# Optimised number of PLS components:  7
# Wavelengths to be discarded  315
# Optimised MSEP  0.0016339394382272072
# RPD CV 1.3131745202467107
# External Validation Goodness-of-Fit 0.2754641132205322
# Optimised number of PLS components:  9
# Wavelengths to be discarded  310
# Optimised MSEP  4.074249935759275e-07
# RPD CV 6.946807410684722
# External Validation Goodness-of-Fit 0.9801670573899971
# Optimised number of PLS components:  9
# Wavelengths to be discarded  266
# Optimised MSEP  4.813861469278742e-07
# RPD CV 6.425799578376996
# External Validation Goodness-of-Fit 0.9794053686286959
# Optimised number of PLS components:  9
# Wavelengths to be discarded  301
# Optimised MSEP  3.4159163816336644e-07
# RPD CV 7.6239605396357755
# External Validation Goodness-of-Fit 0.9874820012729937
# Optimised number of PLS components:  9
# Wavelengths to be discarded  311
# Optimised MSEP  4.810123598665012e-07
# RPD CV 6.430589036577378
# External Validation Goodness-of-Fit 0.9857491174365444
# Optimised number of PLS components:  9
# Wavelengths to be discarded  319
# Optimised MSEP  2.036605443222412e-07
# RPD CV 9.889544605391938
# External Validation Goodness-of-Fit 0.9875193347432941
# Optimised number of PLS components:  9
# Wavelengths to be discarded  318
# Optimised MSEP  0.0003674086494816232
# RPD CV 1.818481988936163
# External Validation Goodness-of-Fit 0.5351449969867934
# Optimised number of PLS components:  9
# Wavelengths to be discarded  290
# Optimised MSEP  0.00044330411229512876
# RPD CV 1.6693536909981124
# External Validation Goodness-of-Fit 0.570282077090543
# Optimised number of PLS components:  8
# Wavelengths to be discarded  271
# Optimised MSEP  0.0003864278875494558
# RPD CV 1.769582672595849
# External Validation Goodness-of-Fit 0.5387751556538536
# Optimised number of PLS components:  9
# Wavelengths to be discarded  324
# Optimised MSEP  0.00040078429520629176
# RPD CV 1.673295932129845
# External Validation Goodness-of-Fit 0.5940349144415964
# Optimised number of PLS components:  8
# Wavelengths to be discarded  315
# Optimised MSEP  0.00031627183704916167
# RPD CV 1.7630933345680215
# External Validation Goodness-of-Fit 0.5655280069246262
# Optimised number of PLS components:  5
# Wavelengths to be discarded  316
# Optimised MSEP  38.69731755384451
# RPD CV 1.0454658902675742
# External Validation Goodness-of-Fit 0.13427824442082525
# Optimised number of PLS components:  5
# Wavelengths to be discarded  317
# Optimised MSEP  42.18590559757399
# RPD CV 1.0292468837332927
# External Validation Goodness-of-Fit 0.05904845191081498
# Optimised number of PLS components:  1
# Wavelengths to be discarded  154
# Optimised MSEP  36.74637481539526
# RPD CV 1.0200167164895813
# External Validation Goodness-of-Fit -0.06949415213883503
# Optimised number of PLS components:  7
# Wavelengths to be discarded  314
# Optimised MSEP  43.37207311421563
# RPD CV 1.047227432484678
# External Validation Goodness-of-Fit -0.06279674009205216
# Optimised number of PLS components:  6
# Wavelengths to be discarded  116
# Optimised MSEP  43.49737988435665
# RPD CV 1.0726617591720908
# External Validation Goodness-of-Fit -0.6460831112089798
# Optimised number of PLS components:  7
# Wavelengths to be discarded  310
# Optimised MSEP  445.1570871949377
# RPD CV 1.6577892779892898
# External Validation Goodness-of-Fit 0.2085341175387444
# Optimised number of PLS components:  7
# Wavelengths to be discarded  301
# Optimised MSEP  522.1568424835029
# RPD CV 1.4667630532102405
# External Validation Goodness-of-Fit 0.5788631085645299
# Optimised number of PLS components:  8
# Wavelengths to be discarded  313
# Optimised MSEP  512.4557736820723
# RPD CV 1.4554737992427011
# External Validation Goodness-of-Fit 0.6403342899788189
# Optimised number of PLS components:  6
# Wavelengths to be discarded  320
# Optimised MSEP  497.20879660618436
# RPD CV 1.4910133099588885
# External Validation Goodness-of-Fit 0.528945519721528
# Optimised number of PLS components:  9
# Wavelengths to be discarded  264
# Optimised MSEP  446.26718638915435
# RPD CV 1.4046459438787826
# External Validation Goodness-of-Fit 0.43736184693196545
# Optimised number of PLS components:  6
# Wavelengths to be discarded  259
# Optimised MSEP  137.90574404664645
# RPD CV 1.419830377444632
# External Validation Goodness-of-Fit 0.5166614031676533
# Optimised number of PLS components:  6
# Wavelengths to be discarded  282
# Optimised MSEP  140.76765039849175
# RPD CV 1.4459857931409104
# External Validation Goodness-of-Fit 0.30269877900526987
# Optimised number of PLS components:  9
# Wavelengths to be discarded  297
# Optimised MSEP  144.80462078240447
# RPD CV 1.409438583431943
# External Validation Goodness-of-Fit 0.38573106557861336
# Optimised number of PLS components:  6
# Wavelengths to be discarded  291
# Optimised MSEP  123.3517272386056
# RPD CV 1.4623944760334922
# External Validation Goodness-of-Fit 0.4244982820733251
# Optimised number of PLS components:  7
# Wavelengths to be discarded  276
# Optimised MSEP  140.0981182053606
# RPD CV 1.3283034224270087
# External Validation Goodness-of-Fit 0.2963809044239585
# Optimised number of PLS components:  5
# Wavelengths to be discarded  274
# Optimised MSEP  2.2798046618530305
# RPD CV 1.73562969872765
# External Validation Goodness-of-Fit 0.4507377601778143
# Optimised number of PLS components:  5
# Wavelengths to be discarded  279
# Optimised MSEP  2.7061967866887686
# RPD CV 1.606845825287594
# External Validation Goodness-of-Fit 0.6400046581552526
# Optimised number of PLS components:  9
# Wavelengths to be discarded  267
# Optimised MSEP  2.6786343520026046
# RPD CV 1.6030364504783017
# External Validation Goodness-of-Fit 0.592824317093346
# Optimised number of PLS components:  5
# Wavelengths to be discarded  264
# Optimised MSEP  2.778591025115337
# RPD CV 1.5627888405998733
# External Validation Goodness-of-Fit 0.6416648423575166
# Optimised number of PLS components:  6
# Wavelengths to be discarded  305
# Optimised MSEP  1.7093649002403453
# RPD CV 1.7332716829971047
# External Validation Goodness-of-Fit 0.16350183270052177
# Optimised number of PLS components:  9
# Wavelengths to be discarded  291
# Optimised MSEP  3.3359669433883092
# RPD CV 1.0357222500890961
# External Validation Goodness-of-Fit -0.08174674192683407
# Optimised number of PLS components:  5
# Wavelengths to be discarded  304
# Optimised MSEP  3.900705336923063
# RPD CV 1.0638426957699765
# External Validation Goodness-of-Fit -0.1653949425243142
# Optimised number of PLS components:  5
# Wavelengths to be discarded  291
# Optimised MSEP  3.9227225576745846
# RPD CV 1.0612638375037995
# External Validation Goodness-of-Fit -0.2290048985973212
# Optimised number of PLS components:  4
# Wavelengths to be discarded  304
# Optimised MSEP  4.014782743277928
# RPD CV 1.0523882620326166
# External Validation Goodness-of-Fit -0.45296357241116736
# Optimised number of PLS components:  5
# Wavelengths to be discarded  291
# Optimised MSEP  3.706736662745081
# RPD CV 1.0057535836303801
# External Validation Goodness-of-Fit -0.0354875235275709

# %%
df_scores_NutesPLSR.to_clipboard()

# %%
from sklearn.model_selection import GridSearchCV
def RF_variable_selection(x, y):
    mse = np.zeros(x.shape[1])
    param_grid = {'n_estimators': [50, 100, 150]}
    rf1 = RandomForestRegressor()
    grid_search = GridSearchCV(estimator = rf1, param_grid=param_grid, cv = 3)
    grid_search.fit(x, y)
    best_rf = grid_search.best_estimator_
    # Sort spectra according to ascending feature_importances
    sorted_ind = np.argsort(best_rf.feature_importances_)
    x_sort = x[:,sorted_ind]
    # discard one wavelength at a time calculate and store mse
    for w in range(0, x_sort.shape[1], 5):
        best_rf.fit(x_sort[:, w:], y)
        predictions = best_rf.predict(x_sort[:, w:])
        p = cross_val_score(best_rf, x_sort[:, w:], y, scoring = 'neg_mean_squared_error')
        p = np.mean(np.abs(p))
        mse[w] = p
    mseminx = np.where(mse==np.min(mse[np.nonzero(mse)]))
    rpd_cv = y.std()/np.sqrt(mse[mseminx][0])
    print('Optimised MSEP ', mse[mseminx][0])
    print("Wavelengths to be discarded:", mseminx[0][0])
    # return the optimised model
    wavD = mseminx[0][0]
    best_rf.fit(x_sort[:, wavD:], y)
    predictions = best_rf.predict(x_sort[:, wavD:])
    print(r2_score(y, predictions))
    return best_rf, mse, wavD, sorted_ind

# %%
## GASEX RF-R ##

print(df_gasex.columns[3:8])
targets = list(df_gasex.columns[3:8])
gkf = GroupKFold(n_splits=5)
scores = {}
for target in targets:
    y = df_gasex[target].values
    x = df_gasex[wavelengths].values
    groups = np.array(df_gasex['Name'])
    scores[target] = []
    i = 0

    for train_ind, test_ind in gkf.split(X = x, y = y, groups = groups):
        #print(df_gasex.loc[test_ind, 'Name'])
        print(target, "CV-{}".format(i))
        rf, mse, wavD, sorted_ind = RF_variable_selection(x=x[train_ind], y= y[train_ind])
        #sns.histplot(x = y[test_ind].flatten(), hue = df_gasex.loc[test_ind, 'Ntreatment'])
        #plt.title(target + '-CV{}'.format(i))
        #plt.show()
        i += 1
        x_test = x[test_ind]
        x_test = x_test[:, sorted_ind]
        x_test = x_test[:, wavD:]
        y_predict = rf.predict(x_test)
        r2 = r2_score(y[test_ind], y_predict)
        print('External Validation Goodness-of-Fit', r2)
        scores[target].append(r2)

df_scores_GasExRFR = pd.DataFrame(scores)
#df_scores_GasExRFR.to_csv('Scores_GasExRFR.csv', index = False)
# Out:
# Index(['E', 'A', 'Ci', 'gsw', 'WUE'], dtype='object')
# E CV-0
# Optimised MSEP  1.036016376067022e-06
# Wavelengths to be discarded: 295
# 0.6019216182750179
# External Validation Goodness-of-Fit 0.027958657754702188
# E CV-1
# Optimised MSEP  1.0289966248527261e-06
# Wavelengths to be discarded: 325
# 0.5827340217358516
# External Validation Goodness-of-Fit -0.3821080675582855
# E CV-2
# Optimised MSEP  9.810026593532773e-07
# Wavelengths to be discarded: 325
# 0.5592787906133985
# External Validation Goodness-of-Fit -0.0824490766925996
# E CV-3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 17
#      14 for train_ind, test_ind in gkf.split(X = x, y = y, groups = groups):
#      15     #print(df_gasex.loc[test_ind, 'Name'])
#      16     print(target, "CV-{}".format(i))
# ---> 17     rf, mse, wavD, sorted_ind = RF_variable_selection(x=x[train_ind], y= y[train_ind])
#      18     #sns.histplot(x = y[test_ind].flatten(), hue = df_gasex.loc[test_ind, 'Ntreatment'])
#      19     #plt.title(target + '-CV{}'.format(i))
#      20     #plt.show()
#      21     i += 1
#
# Cell In[5], line 18, in RF_variable_selection(x, y)
#      16 best_rf.fit(x_sort[:, w:], y)
#      17 predictions = best_rf.predict(x_sort[:, w:])
# ---> 18 p = cross_val_score(best_rf, x_sort[:, w:], y, scoring = 'neg_mean_squared_error')
#      19 p = np.mean(np.abs(p))
#      20 mse[w] = p
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:562, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     559 # To ensure multimetric format is not supported
#     560 scorer = check_scoring(estimator, scoring=scoring)
# --> 562 cv_results = cross_validate(
#     563     estimator=estimator,
#     564     X=X,
#     565     y=y,
#     566     groups=groups,
#     567     scoring={"score": scorer},
#     568     cv=cv,
#     569     n_jobs=n_jobs,
#     570     verbose=verbose,
#     571     fit_params=fit_params,
#     572     pre_dispatch=pre_dispatch,
#     573     error_score=error_score,
#     574 )
#     575 return cv_results["test_score"]
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:309, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     306 # We clone the estimator to make sure that all the folds are
#     307 # independent, and that it is pickle-able.
#     308 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 309 results = parallel(
#     310     delayed(_fit_and_score)(
#     311         clone(estimator),
#     312         X,
#     313         y,
#     314         scorers,
#     315         train,
#     316         test,
#     317         verbose,
#     318         None,
#     319         fit_params,
#     320         return_train_score=return_train_score,
#     321         return_times=True,
#     322         return_estimator=return_estimator,
#     323         error_score=error_score,
#     324     )
#     325     for train, test in indices
#     326 )
#     328 _warn_or_raise_about_fit_failures(results, error_score)
#     330 # For callable scoring, the return type is only know after calling. If the
#     331 # return type is a dictionary, the error scores can now be inserted with
#     332 # the correct key.
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1855, in Parallel.__call__(self, iterable)
#    1853     output = self._get_sequential_output(iterable)
#    1854     next(output)
# -> 1855     return output if self.return_generator else list(output)
#    1857 # Let's create an ID that uniquely identifies the current call. If the
#    1858 # call is interrupted early and that the same instance is immediately
#    1859 # re-used, this id will be used to prevent workers that were
#    1860 # concurrently finalizing a task from the previous call to run the
#    1861 # callback.
#    1862 with self._lock:
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1784, in Parallel._get_sequential_output(self, iterable)
#    1782 self.n_dispatched_batches += 1
#    1783 self.n_dispatched_tasks += 1
# -> 1784 res = func(*args, **kwargs)
#    1785 self.n_completed_tasks += 1
#    1786 self.print_progress()
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:732, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     730         estimator.fit(X_train, **fit_params)
#     731     else:
# --> 732         estimator.fit(X_train, y_train, **fit_params)
#     734 except Exception:
#     735     # Note fit time as time until error
#     736     fit_time = time.time() - start_time
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:456, in BaseForest.fit(self, X, y, sample_weight)
#     445 trees = [
#     446     self._make_estimator(append=False, random_state=random_state)
#     447     for i in range(n_more_estimators)
#     448 ]
#     450 # Parallel loop: we prefer the threading backend as the Cython code
#     451 # for fitting the trees is internally releasing the Python GIL
#     452 # making threading more efficient than multiprocessing in
#     453 # that case. However, for joblib 0.12+ we respect any
#     454 # parallel_backend contexts set at a higher level,
#     455 # since correctness does not rely on using threads.
# --> 456 trees = Parallel(
#     457     n_jobs=self.n_jobs,
#     458     verbose=self.verbose,
#     459     prefer="threads",
#     460 )(
#     461     delayed(_parallel_build_trees)(
#     462         t,
#     463         self.bootstrap,
#     464         X,
#     465         y,
#     466         sample_weight,
#     467         i,
#     468         len(trees),
#     469         verbose=self.verbose,
#     470         class_weight=self.class_weight,
#     471         n_samples_bootstrap=n_samples_bootstrap,
#     472     )
#     473     for i, t in enumerate(trees)
#     474 )
#     476 # Collect newly grown trees
#     477 self.estimators_.extend(trees)
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1855, in Parallel.__call__(self, iterable)
#    1853     output = self._get_sequential_output(iterable)
#    1854     next(output)
# -> 1855     return output if self.return_generator else list(output)
#    1857 # Let's create an ID that uniquely identifies the current call. If the
#    1858 # call is interrupted early and that the same instance is immediately
#    1859 # re-used, this id will be used to prevent workers that were
#    1860 # concurrently finalizing a task from the previous call to run the
#    1861 # callback.
#    1862 with self._lock:
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1784, in Parallel._get_sequential_output(self, iterable)
#    1782 self.n_dispatched_batches += 1
#    1783 self.n_dispatched_tasks += 1
# -> 1784 res = func(*args, **kwargs)
#    1785 self.n_completed_tasks += 1
#    1786 self.print_progress()
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:188, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     185     elif class_weight == "balanced_subsample":
#     186         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 188     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     189 else:
#     190     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py:1320, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1290 @_fit_context(prefer_skip_nested_validation=True)
#    1291 def fit(self, X, y, sample_weight=None, check_input=True):
#    1292     """Build a decision tree regressor from the training set (X, y).
#    1293
#    1294     Parameters
#    (...)
#    1317         Fitted estimator.
#    1318     """
# -> 1320     super()._fit(
#    1321         X,
#    1322         y,
#    1323         sample_weight=sample_weight,
#    1324         check_input=check_input,
#    1325     )
#    1326     return self
#
# File c:\Users\bdub\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
## NUTES RF-R ##

# Same for Nutes
gkf = GroupKFold(n_splits=5)
print(df_nutes.columns[18:30])
targets = list(df_nutes.columns[18:30])

scores = {}
for target in targets:
    y = df_nutes_R2[target].values
    x = df_nutes_R2[wavelengths].values
    groups = np.array(df_nutes_R2['Hybrid'])
    scores[target] = []
    i = 0

    for train_ind, test_ind in gkf.split(X = x, y = y, groups = groups):
        #print(df_gasex.loc[test_ind, 'Name'])
        print(target, "CV-{}".format(i))
        rf, mse, wavD, sorted_ind = RF_variable_selection(x=x[train_ind], y= y[train_ind])
        #sns.histplot(x = y[test_ind].flatten(), hue = df_gasex.loc[test_ind, 'Ntreatment'])
        #plt.title(target + '-CV{}'.format(i))
        #plt.show()
        i += 1
        x_test = x[test_ind]
        x_test = x_test[:, sorted_ind]
        x_test = x_test[:, wavD:]
        y_predict = rf.predict(x_test)
        r2 = r2_score(y[test_ind], y_predict)
        print('External Validation Goodness-of-Fit', r2)
        scores[target].append(r2)

df_scores_NutesRFR = pd.DataFrame(scores)
df_scores_NutesRFR.to_csv('Scores_NutesRFR.csv', index = False)
# Out:
# Index(['N', 'P', 'K', 'Ca', 'Mg', 'Na', 'S', 'Zn', 'Mn', 'Fe', 'Cu', 'B'], dtype='object')
# N CV-0
# Optimised MSEP  0.11946455522281023
# Wavelengths to be discarded: 240
# 0.9491423870758287
# External Validation Goodness-of-Fit 0.5863602407905693
# N CV-1
# Optimised MSEP  0.14313743183251235
# Wavelengths to be discarded: 20
# 0.9421288978858289
# External Validation Goodness-of-Fit 0.5955509191675585
# N CV-2
# Optimised MSEP  0.12269080729064046
# Wavelengths to be discarded: 205
# 0.9441747013782376
# External Validation Goodness-of-Fit 0.6523861679571756
# N CV-3
# Optimised MSEP  0.13994578960591136
# Wavelengths to be discarded: 270
# 0.9475917718819976
# External Validation Goodness-of-Fit 0.5475072013795885
# N CV-4
# Optimised MSEP  0.12289090572839467
# Wavelengths to be discarded: 210
# 0.9466556398338348
# External Validation Goodness-of-Fit 0.5311648964077109
# P CV-0
# Optimised MSEP  0.001106634376216932
# Wavelengths to be discarded: 305
# 0.9368482004583891
# External Validation Goodness-of-Fit 0.5763793416614111
# P CV-1
# Optimised MSEP  0.0012483117216748772
# Wavelengths to be discarded: 295
# 0.9443471639630137
# External Validation Goodness-of-Fit 0.5079645525245063
# P CV-2
# Optimised MSEP  0.0011543164316502469
# Wavelengths to be discarded: 305
# 0.9414615921089267
# External Validation Goodness-of-Fit 0.5477674518814475
# P CV-3
# Optimised MSEP  0.001217426967118227
# Wavelengths to be discarded: 320
# 0.9284312991443313
# External Validation Goodness-of-Fit -0.013717536183039947
# P CV-4
# Optimised MSEP  0.0010892922965079362
# Wavelengths to be discarded: 285
# 0.935117681054217
# External Validation Goodness-of-Fit 0.44546221428573884
# K CV-0
# Optimised MSEP  0.036401823820493895
# Wavelengths to be discarded: 300
# 0.8541557524978012
# External Validation Goodness-of-Fit 0.19307365189113768
# K CV-1
# Optimised MSEP  0.04352482318093594
# Wavelengths to be discarded: 260
# 0.8849014636959697
# External Validation Goodness-of-Fit -0.668565511279088
# K CV-2
# Optimised MSEP  0.041877308441773405
# Wavelengths to be discarded: 330
# 0.8449254610455308
# External Validation Goodness-of-Fit -0.32127234843066255
# K CV-3
# Optimised MSEP  0.03952973540756151
# Wavelengths to be discarded: 305
# 0.8816532174295024
# External Validation Goodness-of-Fit -0.7132787226665107
# K CV-4
# Optimised MSEP  0.04274200353653147
# Wavelengths to be discarded: 330
# 0.8618020092164009
# External Validation Goodness-of-Fit 0.08054868295076512
# Ca CV-0
# Optimised MSEP  0.014365096957962963
# Wavelengths to be discarded: 310
# 0.93799928056416
# External Validation Goodness-of-Fit 0.3204469487843715
# Ca CV-1
# Optimised MSEP  0.0191367906774138
# Wavelengths to be discarded: 80
# 0.9230870539181424
# External Validation Goodness-of-Fit 0.6663398863444341
# Ca CV-2
# Optimised MSEP  0.015420102444532019
# Wavelengths to be discarded: 265
# 0.9228616950843727
# External Validation Goodness-of-Fit 0.3560142002635105
# Ca CV-3
# Optimised MSEP  0.014131608995763545
# Wavelengths to be discarded: 200
# 0.927215033606015
# External Validation Goodness-of-Fit 0.4016169250172077
# Ca CV-4
# Optimised MSEP  0.01471567613563493
# Wavelengths to be discarded: 280
# 0.9364557856018498
# External Validation Goodness-of-Fit 0.21778851970426805
# Mg CV-0
# Optimised MSEP  0.003233797460529102
# Wavelengths to be discarded: 305
# 0.9065385339884297
# External Validation Goodness-of-Fit -0.029553992597816103
# Mg CV-1
# Optimised MSEP  0.003265457796379308
# Wavelengths to be discarded: 55
# 0.8954159553142489
# External Validation Goodness-of-Fit 0.4011329769976989
# Mg CV-2
# Optimised MSEP  0.003018625554187191
# Wavelengths to be discarded: 150
# 0.9151619693644963
# External Validation Goodness-of-Fit 0.21851755894033065
# Mg CV-3
# Optimised MSEP  0.00275685521137931
# Wavelengths to be discarded: 180
# 0.908913179934443
# External Validation Goodness-of-Fit 0.38396899338254
# Mg CV-4
# Optimised MSEP  0.0022016341912169312
# Wavelengths to be discarded: 325
# 0.9156704049357768
# External Validation Goodness-of-Fit -0.017756140339650894
# Na CV-0
# Optimised MSEP  1.1406697354497365e-06
# Wavelengths to be discarded: 325
# 0.9885316312041362
# External Validation Goodness-of-Fit 0.9926784604212056
# Na CV-1
# Optimised MSEP  1.057796398467434e-06
# Wavelengths to be discarded: 285
# 0.9920621778196161
# External Validation Goodness-of-Fit 0.993420095069438
# Na CV-2
# Optimised MSEP  4.155687684729068e-07
# Wavelengths to be discarded: 290
# 0.9932330458838312
# External Validation Goodness-of-Fit 0.872779011535215
# Na CV-3
# Optimised MSEP  1.0869472167487698e-06
# Wavelengths to be discarded: 270
# 0.9947292312127327
# External Validation Goodness-of-Fit 0.9779216856768886
# Na CV-4
# Optimised MSEP  8.677660052910062e-07
# Wavelengths to be discarded: 245
# 0.9963175180163674
# External Validation Goodness-of-Fit 0.9195969533100059
# S CV-0
# Optimised MSEP  0.0006179009165079369
# Wavelengths to be discarded: 310
# 0.9312462926026409
# External Validation Goodness-of-Fit 0.6110274672732843
# S CV-1
# Optimised MSEP  0.0007378267419704446
# Wavelengths to be discarded: 305
# 0.9423770442726023
# External Validation Goodness-of-Fit 0.649955068651094
# S CV-2
# Optimised MSEP  0.0005965467868965518
# Wavelengths to be discarded: 320
# 0.9402533017555027
# External Validation Goodness-of-Fit 0.3766081007854247
# S CV-3
# Optimised MSEP  0.0006252850533442808
# Wavelengths to be discarded: 325
# 0.9372808601231323
# External Validation Goodness-of-Fit 0.43781143188668126
# S CV-4
# Optimised MSEP  0.0005279327793650794
# Wavelengths to be discarded: 220
# 0.9523368060017665
# External Validation Goodness-of-Fit 0.2520650050529635
# Zn CV-0
# Optimised MSEP  47.6320219047619
# Wavelengths to be discarded: 95
# 0.8409423987473799
# External Validation Goodness-of-Fit 0.07867651666761977
# Zn CV-1
# Optimised MSEP  52.728873344280245
# Wavelengths to be discarded: 330
# 0.8570769340089487
# External Validation Goodness-of-Fit -0.009065115885636965
# Zn CV-2
# Optimised MSEP  48.18655069512863
# Wavelengths to be discarded: 220
# 0.8590572751966643
# External Validation Goodness-of-Fit -0.11424574742386273
# Zn CV-3
# Optimised MSEP  52.35847051724138
# Wavelengths to be discarded: 310
# 0.8312595975255116
# External Validation Goodness-of-Fit -0.4105338999999999
# Zn CV-4
# Optimised MSEP  51.119731428571434
# Wavelengths to be discarded: 50
# 0.8498187371177455
# External Validation Goodness-of-Fit -0.7313832783796517
# Mn CV-0
# Optimised MSEP  891.5909242328041
# Wavelengths to be discarded: 315
# 0.9127884306445146
# External Validation Goodness-of-Fit 0.19151953788437703
# Mn CV-1
# Optimised MSEP  971.5501785960593
# Wavelengths to be discarded: 215
# 0.9131250670155577
# External Validation Goodness-of-Fit 0.419296331257369
# Mn CV-2
# Optimised MSEP  873.1986780295565
# Wavelengths to be discarded: 300
# 0.9177707102637982
# External Validation Goodness-of-Fit 0.4867023090921747
# Mn CV-3
# Optimised MSEP  901.8849244581281
# Wavelengths to be discarded: 235
# 0.9264296226590932
# External Validation Goodness-of-Fit 0.4178598519286588
# Mn CV-4
# Optimised MSEP  566.4657925808348
# Wavelengths to be discarded: 325
# 0.9414793796442875
# External Validation Goodness-of-Fit 0.22206675914714658
# Fe CV-0
# Optimised MSEP  208.72182661963552
# Wavelengths to be discarded: 300
# 0.9100157422476595
# External Validation Goodness-of-Fit 0.48895364950563813
# Fe CV-1
# Optimised MSEP  220.21283551724142
# Wavelengths to be discarded: 305
# 0.9159906311105855
# External Validation Goodness-of-Fit 0.17194612971262846
# Fe CV-2
# Optimised MSEP  191.0938147783251
# Wavelengths to be discarded: 325
# 0.9102956125524707
# External Validation Goodness-of-Fit -0.06459668193947943
# Fe CV-3
# Optimised MSEP  223.9944793869732
# Wavelengths to be discarded: 290
# 0.9078147301930632
# External Validation Goodness-of-Fit 0.15937871625086908
# Fe CV-4
# Optimised MSEP  188.74266285714285
# Wavelengths to be discarded: 150
# 0.8933976748825018
# External Validation Goodness-of-Fit 0.010179082482088986
# Cu CV-0
# Optimised MSEP  4.368008677248676
# Wavelengths to be discarded: 330
# 0.9013618068269977
# External Validation Goodness-of-Fit 0.3737173547199578
# Cu CV-1
# Optimised MSEP  4.405660985221675
# Wavelengths to be discarded: 325
# 0.9183455778395266
# External Validation Goodness-of-Fit 0.4966863879003559
# Cu CV-2
# Optimised MSEP  4.1583731253420915
# Wavelengths to be discarded: 325
# 0.9256426809306676
# External Validation Goodness-of-Fit 0.3205662835249041
# Cu CV-3
# Optimised MSEP  4.8937833990147785
# Wavelengths to be discarded: 330
# 0.9149076558747665
# External Validation Goodness-of-Fit 0.3478410994764398
# Cu CV-4
# Optimised MSEP  2.7400672663139334
# Wavelengths to be discarded: 305
# 0.9470495262894998
# External Validation Goodness-of-Fit 0.006043722943722796
# B CV-0
# Optimised MSEP  4.135209664902998
# Wavelengths to be discarded: 260
# 0.8576838486403504
# External Validation Goodness-of-Fit -0.22985270245487133
# B CV-1
# Optimised MSEP  5.719242266009852
# Wavelengths to be discarded: 165
# 0.8379264697839759
# External Validation Goodness-of-Fit -0.10218767123287686
# B CV-2
# Optimised MSEP  4.89223150519978
# Wavelengths to be discarded: 325
# 0.8394034321538625
# External Validation Goodness-of-Fit -0.4803277918781723
# B CV-3
# Optimised MSEP  5.156879753694581
# Wavelengths to be discarded: 325
# 0.8379783993212669
# External Validation Goodness-of-Fit -1.28397638248848
# B CV-4
# Optimised MSEP  4.494248465608466
# Wavelengths to be discarded: 235
# 0.8359685195599198
# External Validation Goodness-of-Fit -0.4967850332594237

# %%
# SVM
from sklearn.svm import SVR

def SVM_R(X, y):
    param_grid = {'kernel': ['linear', 'poly'],
                  'C': [0.1, 0.5, 1, 5, 10]}
    svr = SVR()
    grid_search = GridSearchCV(estimator=svr, param_grid=param_grid, cv = 3)
    grid_search.fit(X, y)
    best_svr = grid_search.best_estimator_
    return best_svr

# %%
## GASEX SVR ##

print(df_gasex.columns[3:8])
targets = list(df_gasex.columns[3:8])
gkf = GroupKFold(n_splits=5)
scores = {}
for target in targets:
    y = df_gasex[target].values
    x = df_gasex[wavelengths].values
    groups = np.array(df_gasex['Name'])
    scores[target] = []
    i = 0

    for train_ind, test_ind in gkf.split(X = x, y = y, groups = groups):
        #print(df_gasex.loc[test_ind, 'Name'])
        print(target, "CV-{}".format(i))
        svr = SVM_R(x[train_ind], y[train_ind])
        #sns.histplot(x = y[test_ind].flatten(), hue = df_gasex.loc[test_ind, 'Ntreatment'])
        #plt.title(target + '-CV{}'.format(i))
        #plt.show()
        i += 1
        x_test = x[test_ind]
        y_predict = svr.predict(x_test)
        r2 = r2_score(y[test_ind], y_predict)
        print('External Validation Goodness-of-Fit', r2)
        scores[target].append(r2)

df_scores_GasExSVR = pd.DataFrame(scores)
df_scores_GasExSVR.to_csv('Scores_GasExSVR.csv', index = False)
# Out:
# Index(['E', 'A', 'Ci', 'gsw', 'WUE'], dtype='object')
# E CV-0
# E-CV0
# External Validation Goodness-of-Fit -0.09120555784374185
# E CV-1
# E-CV1
# External Validation Goodness-of-Fit -0.17394720902688143
# E CV-2
# E-CV2
# External Validation Goodness-of-Fit -0.13360718710612973
# E CV-3
# E-CV3
# External Validation Goodness-of-Fit -0.4299017142163648
# E CV-4
# E-CV4
# External Validation Goodness-of-Fit -0.1465565943610656
# A CV-0
# A-CV0
# External Validation Goodness-of-Fit 0.18903480965716923
# A CV-1
# A-CV1
# External Validation Goodness-of-Fit 0.14022099141101718
# A CV-2
# A-CV2
# External Validation Goodness-of-Fit 0.15769344619082826
# A CV-3
# A-CV3
# External Validation Goodness-of-Fit -0.03747270197287311
# A CV-4
# A-CV4
# External Validation Goodness-of-Fit 0.1783224938509096
# Ci CV-0
# Ci-CV0
# External Validation Goodness-of-Fit 0.1053464583692848
# Ci CV-1
# Ci-CV1
# External Validation Goodness-of-Fit -0.1020960532115045
# Ci CV-2
# Ci-CV2
# External Validation Goodness-of-Fit 0.042629700458964304
# Ci CV-3
# Ci-CV3
# External Validation Goodness-of-Fit 0.052021271620390275
# Ci CV-4
# Ci-CV4
# External Validation Goodness-of-Fit 0.0230165371649379
# gsw CV-0
# gsw-CV0
# External Validation Goodness-of-Fit 0.07077174862502822
# gsw CV-1
# gsw-CV1
# External Validation Goodness-of-Fit 0.04101423468537535
# gsw CV-2
# gsw-CV2
# External Validation Goodness-of-Fit -0.45789803938058893
# gsw CV-3
# gsw-CV3
# External Validation Goodness-of-Fit -0.4495833840971035
# gsw CV-4
# gsw-CV4
# External Validation Goodness-of-Fit -0.20224583916882644
# WUE CV-0
# WUE-CV0
# External Validation Goodness-of-Fit 0.15615794350490952
# WUE CV-1
# WUE-CV1
# External Validation Goodness-of-Fit -0.16041542670656495
# WUE CV-2
# WUE-CV2
# External Validation Goodness-of-Fit 0.02640095552971422
# WUE CV-3
# WUE-CV3
# External Validation Goodness-of-Fit 0.01777430532995128
# WUE CV-4
# WUE-CV4
# External Validation Goodness-of-Fit 0.0248440245214272

# %%
## NUTES SVR ##

# Same for Nutes
gkf = GroupKFold(n_splits=5)
print(df_nutes.columns[18:30])
targets = list(df_nutes.columns[18:30])

scores = {}
for target in targets:
    y = df_nutes_R2[target].values
    x = df_nutes_R2[wavelengths].values
    groups = np.array(df_nutes_R2['Hybrid'])
    scores[target] = []
    i = 0

    for train_ind, test_ind in gkf.split(X = x, y = y, groups = groups):
        #print(df_gasex.loc[test_ind, 'Name'])
        print(target, "CV-{}".format(i))
        svr = SVM_R(x[train_ind], y[train_ind])
        print(target + '-CV{}'.format(i))
        #sns.histplot(x = y[test_ind].flatten(), hue = df_gasex.loc[test_ind, 'Ntreatment'])
        #plt.title(target + '-CV{}'.format(i))
        #plt.show()
        i += 1
        x_test = x[test_ind]
        y_predict = svr.predict(x_test)
        r2 = r2_score(y[test_ind], y_predict)
        print('External Validation Goodness-of-Fit', r2)
        scores[target].append(r2)

df_scores_NutesSVR = pd.DataFrame(scores)
df_scores_NutesSVR.to_csv('Scores_NutesSVR.csv', index = False)
# Out:
# Index(['N', 'P', 'K', 'Ca', 'Mg', 'Na', 'S', 'Zn', 'Mn', 'Fe', 'Cu', 'B'], dtype='object')
# N CV-0
# N-CV0
# External Validation Goodness-of-Fit 0.685050019279642
# N CV-1
# N-CV1
# External Validation Goodness-of-Fit 0.6571002435068787
# N CV-2
# N-CV2
# External Validation Goodness-of-Fit 0.7038904352846914
# N CV-3
# N-CV3
# External Validation Goodness-of-Fit 0.5456668920774574
# N CV-4
# N-CV4
# External Validation Goodness-of-Fit 0.7598936882598162
# P CV-0
# P-CV0
# External Validation Goodness-of-Fit -0.0017617825500118034
# P CV-1
# P-CV1
# External Validation Goodness-of-Fit -0.00560482374335014
# P CV-2
# P-CV2
# External Validation Goodness-of-Fit -0.01695792591486489
# P CV-3
# P-CV3
# External Validation Goodness-of-Fit -0.0004761699476019121
# P CV-4
# P-CV4
# External Validation Goodness-of-Fit -0.30998060960543894
# K CV-0
# K-CV0
# External Validation Goodness-of-Fit 0.2773130131712417
# K CV-1
# K-CV1
# External Validation Goodness-of-Fit -0.2964429200309593
# K CV-2
# K-CV2
# External Validation Goodness-of-Fit 0.2307689491506969
# K CV-3
# K-CV3
# External Validation Goodness-of-Fit -0.005253988625363082
# K CV-4
# K-CV4
# External Validation Goodness-of-Fit 0.3207122992147271
# Ca CV-0
# Ca-CV0
# External Validation Goodness-of-Fit 0.4229949077002282
# Ca CV-1
# Ca-CV1
# External Validation Goodness-of-Fit 0.7018936908848435
# Ca CV-2
# Ca-CV2
# External Validation Goodness-of-Fit 0.5620545602172817
# Ca CV-3
# Ca-CV3
# External Validation Goodness-of-Fit 0.443099545656345
# Ca CV-4
# Ca-CV4
# External Validation Goodness-of-Fit 0.33314713804036356
# Mg CV-0
# Mg-CV0
# External Validation Goodness-of-Fit -0.4233564584082734
# Mg CV-1
# Mg-CV1
# External Validation Goodness-of-Fit 0.04926658313631693
# Mg CV-2
# Mg-CV2
# External Validation Goodness-of-Fit -0.2705387227936098
# Mg CV-3
# Mg-CV3
# External Validation Goodness-of-Fit 0.32490914886649946
# Mg CV-4
# Mg-CV4
# External Validation Goodness-of-Fit 0.3342379828376102
# Na CV-0
# Na-CV0
# External Validation Goodness-of-Fit -0.006617647058823062
# Na CV-1
# Na-CV1
# External Validation Goodness-of-Fit -0.006163202535184986
# Na CV-2
# Na-CV2
# External Validation Goodness-of-Fit -0.02167541967551334
# Na CV-3
# Na-CV3
# External Validation Goodness-of-Fit -0.0061822176514580995
# Na CV-4
# Na-CV4
# External Validation Goodness-of-Fit -0.0012723995334529281
# S CV-0
# S-CV0
# External Validation Goodness-of-Fit -0.26243646298021095
# S CV-1
# S-CV1
# External Validation Goodness-of-Fit -0.8408326234854391
# S CV-2
# S-CV2
# External Validation Goodness-of-Fit -0.68699868797923
# S CV-3
# S-CV3
# External Validation Goodness-of-Fit -1.173033443855572
# S CV-4
# S-CV4
# External Validation Goodness-of-Fit -0.0580810064739401
# Zn CV-0
# Zn-CV0
# External Validation Goodness-of-Fit 0.08801210522677727
# Zn CV-1
# Zn-CV1
# External Validation Goodness-of-Fit 0.10125166488995896
# Zn CV-2
# Zn-CV2
# External Validation Goodness-of-Fit -0.18069337942236352
# Zn CV-3
# Zn-CV3
# External Validation Goodness-of-Fit -0.04090437762011878
# Zn CV-4
# Zn-CV4
# External Validation Goodness-of-Fit -0.32537777835783954
# Mn CV-0
# Mn-CV0
# External Validation Goodness-of-Fit 0.41410795998247807
# Mn CV-1
# Mn-CV1
# External Validation Goodness-of-Fit 0.5559761998180991
# Mn CV-2
# Mn-CV2
# External Validation Goodness-of-Fit 0.40187949421710045
# Mn CV-3
# Mn-CV3
# External Validation Goodness-of-Fit 0.45353939964291645
# Mn CV-4
# Mn-CV4
# External Validation Goodness-of-Fit 0.15971483927472352
# Fe CV-0
# Fe-CV0
# External Validation Goodness-of-Fit 0.5282875304445893
# Fe CV-1
# Fe-CV1
# External Validation Goodness-of-Fit 0.4342819727271462
# Fe CV-2
# Fe-CV2
# External Validation Goodness-of-Fit 0.5252457974567598
# Fe CV-3
# Fe-CV3
# External Validation Goodness-of-Fit 0.2291059633425777
# Fe CV-4
# Fe-CV4
# External Validation Goodness-of-Fit -0.010998594507964032
# Cu CV-0
# Cu-CV0
# External Validation Goodness-of-Fit 0.5529712568141398
# Cu CV-1
# Cu-CV1
# External Validation Goodness-of-Fit 0.6752460499983269
# Cu CV-2
# Cu-CV2
# External Validation Goodness-of-Fit 0.6184599252574394
# Cu CV-3
# Cu-CV3
# External Validation Goodness-of-Fit 0.6326259476115208
# Cu CV-4
# Cu-CV4
# External Validation Goodness-of-Fit 0.007647949803846421
# B CV-0
# B-CV0
# External Validation Goodness-of-Fit -0.02787848702438067
# B CV-1
# B-CV1
# External Validation Goodness-of-Fit -0.023679104153576436
# B CV-2
# B-CV2
# External Validation Goodness-of-Fit -0.005412072269890933
# B CV-3
# B-CV3
# External Validation Goodness-of-Fit -0.5653854618772896
# B CV-4
# B-CV4
# External Validation Goodness-of-Fit -0.26467113537403386
